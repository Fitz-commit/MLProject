# %% [markdown]
# # Zeitreihenanalyse durch maschinelles Lernen: Feature-Extraktion im Vergleich zu Rohdatenverarbeitung als Grundlage für Klassifikation von Schlafphasen

# %% [markdown]
# Autor: Tim Federolf & Phillip Hörr

# %% [markdown]
# Diese Arbeit beschäftigt sich mit der Analyse von Zeitreihendaten im Kontext der schlafbezogenen Erregungsforschung. Es wird der Datensatz "Comprehensive Polysomnography (CPS) Dataset: A Resource for Sleep-Related Arousal Research" untersucht.
#
# Das Ziel dieser Untersuchung ist die Entwicklung von maschinellen Lernmodellen zur Klassifikation verschiedener Schlafphasen. Im Detail vergleicht diese Ausarbeitung Methoden der Merkmalsextraktion mit der Verarbeitung von Rohdaten durch Deep-Learning-Modelle. Die daraus resultierenden Modelle werden primär hinsichtlich ihrer Genauigkeit bei der Klassifikation von Schlafphasen bewertet. Sekundäre Bewertungskriterien umfassen den Aufwand für die Erstellung der Modelle, wie z. B. erforderliche Rechenleistung, notwendiges Fine-Tuning und benötigte Datenmenge.
#
# Die Merkmalsextraktion wird durch verschiedene Transformer durchgeführt, die die Rohdaten in spezifische Metadaten bzw. Features umwandeln. Basierend auf den daraus resultierenden Feature-Vektoren können standardisierte Modelle entwickelt werden. Im Vergleich wird die Performance von Deep-Learning-Modellen gemessen, die auf den Rohdaten trainiert werden und keine Abstraktionsschicht durchlaufen, die die Daten in Vektoren vorbereitet.
#
# Die Modellierung wurde hauptsächlich mit dem aeon Toolkit durchgeführt, welches sich auf die Verarbeitung von Zeitreihendaten spezialisiert hat. Ergänzend wurden die Bibliotheken sklearn und TensorFlow verwendet.

# %% [markdown]
# Die Struktur dieser Ausarbeitung ist in sechs Kapitel gegliedert. Zunächst werden die Daten importiert, um sie im weiteren Verlauf der Ausarbeitung zur Konstruktion der Modelle verwenden zu können. Im nächsten Schritt werden diese Rohdaten in ein kompatibles Format überführt, welches von den verwendeten Bibliotheken anerkannt wird. Anschließend erfolgt eine detaillierte Analyse der Rohdaten, um bestimmte Muster oder allgemeine Faktoren im Datensatz zu identifizieren, die bei der Bewertung der Ergebnisse hilfreich sein können. In den darauffolgenden Kapiteln werden die Feature-Extraction-Modelle sowie die Deep-Learning-Modelle entwickelt. Im abschließenden Kapitel findet eine Evaluation der Ergebnisse statt, wobei die allgemeine Performance der Modelle innerhalb des Datenkontextes betrachtet und daraus ein Fazit abgeleitet wird.

# %%
import os

import numpy
from aeon.transformations.collection import MinMaxScaler
from aeon.transformations.collection.feature_based import Catch22
from aeon.classification.feature_based import Catch22Classifier
from aeon.classification.convolution_based import RocketClassifier
from aeon.classification.deep_learning import TimeCNNClassifier
from aeon.transformations.collection.convolution_based import Rocket
from aeon.utils.validation import is_univariate, has_missing, is_equal_length
from mlcroissant import Dataset
import wfdb

from utils import read_event_file_as_list, yml_import, get_question_mapping
import logging
from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import RidgeClassifierCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report
# Out:
# 2025-01-14 20:16:36.851038: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736882196.873339     908 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736882196.879866     908 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-14 20:16:36.905223: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Für die Arbeit mit Tensorflow wurde eine umgebung aufgesetzt, welche automatisch die GPU für das berechnen der Deep-Leanring Modele verwendet. Dies hat den primären Hintergrund das die Berechung der Modelle auf einer CPU zu resourcen und zeitintensiv wäre.

# %%
import tensorflow as tf

gpus = tf.config.list_physical_devices("GPU")

if gpus:
    for gpu in gpus:
        print("Found a GPU with the name:", gpu)
else:
    print("Failed to detect a GPU.")
# Out:
# Found a GPU with the name: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
from sklearn.exceptions import UndefinedMetricWarning 
import warnings

warnings.filterwarnings("ignore", category=UndefinedMetricWarning)
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # 1. Data Import

# %% [markdown]
# Das folgende Kapitel beschäftigt sich hauptsächlich mit dem Import der Daten. Basis dieses kapitel sind die Methoden load_signals() und load_analysis_and_yaml_files(), welche in einer abgewandelten Form aus der Load.py extrahiert wurden.

# %%
ANALYSIS_DATA_FILES = ["Schlafprofil.txt"]

YAML_DATA_FILES = []

# %% [markdown]
# Im ersten Schritt werden die sämtliche TXT und YAML Files, welche zum Bau des Models benötigt werden eingelsen. Für den Bau der Modele ist in dieser Ausarbeitung nur "Schlafprofil.txt" nötig, welche die Schlafphasen des jeweiligen Patienten enthält. Diese dienen bei dem Bau der Modele als Labels

# %%
def load_signals(base_path, sample_ids):
    psg_files = [os.path.join(base_path, sample_id, 'PSG', sample_id) for sample_id in sample_ids]

    signal_data = {}

    for psg_file in tqdm(psg_files, desc='Loading signals'):
        record = wfdb.rdrecord(psg_file)
        signal = np.transpose(record.p_signal)

        sort_index = np.argsort(record.sig_name)
        sorted_sig_name = np.array(record.sig_name)[sort_index]
        sorted_signal = signal[sort_index]

        signal_data[record.record_name] = {signal_name: signal_data for signal_name, signal_data in zip(sorted_sig_name, sorted_signal)}

    return signal_data

def load_analysis_and_yaml_files(base_path, sample_ids, analysis_data_files=ANALYSIS_DATA_FILES, yaml_data_files=YAML_DATA_FILES):

    analysis_data = {}
    yaml_data = {}
    logging.info(f'Loading {len(yaml_data_files)} yaml files and {len(analysis_data_files)} analysis files.')
    for sample_id in tqdm(sample_ids, desc='Loading analysis and yaml files'):
        analysis_data[sample_id] = {}
        yaml_data[sample_id] = {}

        for analysis_data_file in analysis_data_files:
            path = os.path.join(base_path, sample_id, 'PSG', 'Analysedaten', analysis_data_file)
            try:
                file_as_list, _, _ = read_event_file_as_list(path)
                analysis_data[sample_id][analysis_data_file] = file_as_list
            except FileNotFoundError:
                print(f"Warning: File {analysis_data_file} from sample {sample_id} not found. Leaving it empty.")
                analysis_data[sample_id][analysis_data_file] = None

        for yaml_data_file in yaml_data_files:
            path = os.path.join(base_path, sample_id, 'YAML', yaml_data_file)
            try:
                data = yml_import(path)
                yaml_data[sample_id][yaml_data_file] = data
            except FileNotFoundError:
                print(f"Warning: File {yaml_data_file} from sample {sample_id} not found. Leaving it empty.")
                yaml_data[sample_id][yaml_data_file] = None

    return analysis_data, yaml_data

def create_feature_vektor_df(viewed_features, block_size):
    df_main = pd.DataFrame()
    
    for patient, patient_data in signals.items():
        df_patient = pd.DataFrame()
        for feature in viewed_features:
            
            reshaped_array = [patient_data[feature][i:i+block_size] for i in range(0, len(patient_data[feature]), block_size)]

            df = pd.DataFrame({
                feature: reshaped_array
            }) 
            #if add_metadata:
                #df[f'{feature}_Min_Wert'] = df.min(axis=1)
                #df[f'{feature}_Max_Wert'] = df.max(axis=1)
                #df[f'{feature}_Mean_Wert'] = df.mean(axis=1)
                #df[f'{feature}_Median'] = df.median(axis=1)
                #df[f'{feature}_Std_Wert'] = df.std(axis=1)
                #df[f'{feature}_Amplitude'] = df.max(axis=1) - df.min(axis=1)
    
            # Überprüfen ob das Feature schon existiert
            if any(col.startswith(feature) for col in df_patient.columns):
                # Vertikales Kombinieren (neue Zeilen)
                df_patient = pd.concat([df_patient, df], axis=0, ignore_index=True)
            else:
                # Horizontales Kombinieren (neue Spalten)
                if df_patient.empty:
                    df_patient = df  # Erste Daten einfach zuweisen
                else:
                    df_patient = pd.concat([df_patient,df], axis=1)
    
        df_main = pd.concat([df_main, df_patient], axis=0, ignore_index=True)
    
    return df_main



def evaluate_model(test_labels, predictions):
    # Modell evaluieren
    accuracy = accuracy_score(test_labels, predictions)
    print(f"Genauigkeit des Modells: {accuracy:.2f}")

    print("Eindeutige Werte in label_test:", np.unique(test_labels))
    print("Eindeutige Werte in data_pred:", np.unique(predictions))

    report = classification_report(test_labels, predictions)
    print(report)

    cm = confusion_matrix(test_labels, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(test_labels))
    disp.plot(cmap="Blues_r", values_format='d')
    plt.grid(False)
    plt.show()

def calculate_label_share(labels):
    unique_values = np.unique(labels)
    counts =[]
    for value in unique_values:
        counter =0
        for label in labels:
            if value == label:
                counter +=1
        counts.append(counter)

    percentage = [ round((100/len(labels))* count, 2) for count in counts]    
    
    return percentage, counts

# %% [markdown]
# Der vorherige Abschnitt stammt aus der Datei load.py. Der Code wurde entsprechend modifiziert, um innerhalb eines Jupyter-Notebooks ausführbar zu sein.
#
# Im Code werden sowohl die Signaldaten als auch die initial definierten TXT- und YAML-Dateien eingelesen. Diese Daten werden in den Variablen signals, yaml_data und analysis_data gespeichert. Dabei ist zu beachten, dass ausschließlich die Patientendaten importiert werden, die in einem separaten data-Verzeichnis abgelegt sind. Der Datenbestand kann daher schrittweise erweitert werden, indem neue Patientendaten in diesem Ordner hinzugefügt werden.

# %%
dataset = Dataset(jsonld="croissant.json")

base_path = dataset.metadata.url
print(f"Base path: {base_path}")
directory = os.getcwd()
base_path = os.path.join(directory, base_path)
    
sample_ids = os.listdir(base_path)
analysis_data_files = ANALYSIS_DATA_FILES
yaml_data_files = YAML_DATA_FILES

signals = load_signals(base_path, sample_ids)
logging.info(f'Loaded {len(signals)} signals.')

analysis_data, yaml_data = load_analysis_and_yaml_files(base_path, sample_ids, analysis_data_files, yaml_data_files)
logging.info(f'Loaded analysis data for {len(analysis_data)} samples.')
logging.info(f'Loaded YAML data for {len(yaml_data)} samples.')

# Optional: Get the question mapping
yaml_data_mapped = get_question_mapping(yaml_data)
# Out:
# WARNING:absl:Found the following 1 warning(s) during the validation:
#   -  [Metadata(Comprehensive Polysomnography (CPS) Dataset: A Resource for Sleep-Related Arousal Research)] Property "https://schema.org/datePublished" is recommended, but does not exist.
# Base path: ./data
# ...
# Loading analysis and yaml files: 100%|██████████| 7/7 [00:00<00:00, 33.14it/s]

# %% [markdown]
# # 2. Data Formatting

# %% [markdown]
# Nach dem erfolgreichen Import der Daten sind diese nun in einem standardisierten Python-Dictionary verfügbar. Dabei erfolgt die Betrachtung jedes einzelnen Patienten weiterhin separat.
#
# Die importierten Daten müssen nun formatiert und strukturiert werden.

# %%
#features =["C3:A2","F4"]
features =["C3:A2"]
# Die Größe der Blöcke 
time_interval_block_size = 7680

# %% [markdown]
# Im Rahmen dieser Untersuchung konzentrierten wir uns speziell auf den EEG-Kanal C3:A2 eines jeden Patienten, der in der Fachliteratur als Referenzpunkt zur optimalen Kategorisierung verschiedener Schlafphasen bezeichnet wird. Die Struktur des Notebooks ist jedoch flexibel und kann durch Hinzufügen weiterer EEG-Kanäle wie beispielsweise F4 erweitert werden. Dies ermöglicht die Konfrontation von Modellen mit unterschiedlichen Betrachtungsweisen der Daten, verlängert jedoch die Modellkonstruktion erheblich, da die Datenmenge mit jedem zusätzlichen Kanal verdoppelt wird.
#
# Um die Daten in eine einheitliche Struktur zu überführen, müssen sie zunächst synchronisiert werden. Die Datenpunkte des C3:A2-Kanals liegen in einer losen Array-Struktur vor, während die Labels in 30-Sekunden-Intervallen definiert sind. Daher muss ermittelt werden, wie viele Datenpunkte in einem 30-Sekunden-Intervall passen. Gemäß der Datenbeschreibung wurden diese mit 256 Hertz aufgezeichnet. 30 Sekunden x 256 Hertz = 7680 Datenpunkte pro 30-Sekunden-Intervall. Folglich müssen die Rohdatenpunkte in 7680 lange Sub-Arrays unterteilt werden. Dies erfolgt durch die Methode create_feature_vector_array.

# %%
def create_feature_vektor_array(viewed_features, block_size):
    main_data_array = []
    main_label_array= []
    
    for patient, patient_data in signals.items():
        label_array = [intervall[1] for intervall in analysis_data[patient]["Schlafprofil.txt"]]
        data_array = []
        to_be_deleted_label=[]
        
        #TODO eventuell exception werfen wenn man Arrays mit unterschiedlicher länge miteinbringt

        counter=0
        for i in range(0, len(patient_data["C3:A2"]), block_size):
            time_intervall_with_features=[]
            

            single_block= []
            for feature in viewed_features:
                single_block.append(patient_data[feature][i:i+block_size])
            
            '''Überprüfung ob alle Blöcke die selbe länge haben, falls nicht werden diese mit anderen Längen entfernt.
            Passiert meist nur am Ende falls die Messung innerhalb eines Intervalls unterbrochen wurde'''
            if all(len(data_channel_block)== block_size for data_channel_block in single_block):
                    time_intervall_with_features.extend(single_block)
            else:
                to_be_deleted_label.append(counter-1)
                '''Theoretisch geht hier auch
                label_array.pop(counter-1)
                counter -=1
                '''
            
            #Kein leeres Array soll in die Liste kommen.
            if time_intervall_with_features:
                data_array.append(time_intervall_with_features)
                #main_data_array.append(np.array(time_intervall_with_features))
                
                
            counter +=1
            '''Indexe werden alle aufeinmal rausgelöscht, weil beim einzelnen Löschen die nachfolgenden 
            Elemente nachrücken und so die counter Variable nicht mehr synchron wäre'''
            for label_index in to_be_deleted_label: 
                label_array.pop(label_index)
                
        #Vereinzelte Datensätze (z.b. 0Ah95Qw18puf1JsnrKBA6u8XXZLlMIQJ) haben ein Label zu viel am Ende, das wird hier abgeschnitten.   
        if len(data_array) != len(label_array):
            label_array = label_array[:len(data_array)]
        main_label_array.extend(label_array)
        main_data_array.extend(np.array(data_array))
                
        
    return main_label_array, main_data_array

# %% [markdown]
# Für die Anwendung des Aeon Toolkits ist es erforderlich, dass die Daten im Format (n_cases, n_channels, n_timepoints) vorliegen. Diese Struktur entspricht einem dreidimensionalen Numpy-Array, das ohne zusätzliche Formatierung direkt an die Klassifikatoren des Aeon Toolkits übergeben werden kann. In unserer Betrachtung stehen die Variablen für:
#
# - n_cases: Anzahl der 30-sekündigen Intervalle
# - n_channels: Anzahl der zu betrachtenden Kanäle (1 -> C3:A2)
# - n_timepoints: Anzahl der Zeitpunkte in einem Intervall (7680)
#
# Es ist wichtig zu beachten, dass die Daten logisch zusammengehalten werden. Dies bedeutet, dass im resultierenden Array alle Datenintervalle des zuerst eingelesenen Patienten in zeitlicher Reihenfolge enthalten sind, gefolgt von den Patientendaten der jeweils nachfolgenden Patienten. Auf diese Weise entsteht aus mehreren Patientendatensätzen ein kontinuierlicher und zeitlich korrekt geordneter Strom von Datenpunkten. Entsprechend wird dies auch für das Label-Array durchgeführt, wobei dieses ein eindimensionales Array darstellt, das die Labels der jeweiligen Datenintervalle in derselben zeitlichen und patientenspezifischen Reihenfolge enthält.

# %%
label_y_array,data_x_array= create_feature_vektor_array(features, time_interval_block_size)
print("Länge des Datenarrays:" + str(len(data_x_array)))
print("Länge des Labelarrays:" + str(len(label_y_array)))
# Out:
# Länge des Datenarrays:6493
# Länge des Labelarrays:6493

# %% [markdown]
# Nun, da die Daten in einem kohärenten Format vorliegen, müssen diese von verbleibenden Anomalien und Artefakten bereinigt werden. Im folgenden Abschnitt werden daher sämtliche Labels und die dazugehörigen Datenintervalle, die nicht den Standardschlafphasen entsprechen, aus der Hauptdatenstruktur entfernt. Das Ergebnis wird in den Variablen label_y_array_filtered und data_x_array_filtered gespeichert. Dieses Vorgehen dient dazu, die in der Datei Schlafprofil.txt vorkommenden "Artefakt"-Labels zu entfernen.

# %%
#Hier werden die Artefakt-Labels rausgeworfen
included_values = {"N3","N2","N1","Rem","Wach"}

label_y_array_filtered = [val for i, val in enumerate(label_y_array) if val in included_values]
data_x_array_filtered = [data_x_array[i] for i, val in enumerate(label_y_array) if val in included_values]


print("Gefiltertes Label-Array:", str(len(label_y_array_filtered)) )
print("Gefiltertes Daten-Array:", str(len(data_x_array_filtered)) )
# Out:
# Gefiltertes Label-Array: 6479
# Gefiltertes Daten-Array: 6479

# %% [markdown]
# # 3. Data Understanding

# %% [markdown]
# Das folgende Kapitel konzentriert sich auf die Analyse der Daten. Die eingelesenen Daten werden dabei aus verschiedenen Blickwinkeln betrachtet, um markante Merkmale zu identifizieren, die bei der Bewertung oder Konstruktion von Modellen hilfreich sein könnten. Dieses Kapitel wird in die allgemeine Datenanalyse und die Labelanalyse untergliedert.

# %% [markdown]
# ## 3.1 Data Analysis

# %% [markdown]
# Im folgenden Kapitel wird zusammengefasst, welche Patientendaten im aktuellen Datenkontext verwendet werden. Des Weiteren werden die vorhandenen Kanäle visualisiert und einfache Metadaten wie der Min-Max-Wert berechnet. Zusätzlich werden die Daten analysiert, um gegebenenfalls auf fehlende Werte oder Störungen hinzuweisen. Dies dient der allgemeinen Überprüfung der Datenstruktur.

# %%
print("Current scope of users:")

for patient_ids in signals.keys():
    print(patient_ids)
# Out:
# Current scope of users:
# 0Ah95Qw18puf1JsnrKBA6u8XXZLlMIQJ
# 0pdaTB9613iRUlhUJRAYvKmMQcOV3TYn
# 0vjSLbBj2sckqQam3tZ92QLDpQNYqaa0
# 1RLVk0ocGDZLI8RRhPglAc4I3gMSLqvu
# Yp6NRNtFSjbjdcFWN7Q1ATwOir9wrBNw
# yWLp2YwYQlKqoSR14JUiazZzcywX8Xj8
# ZFkXoBHziu00Toye78g1YdKm5P0bA0dY

# %%
global_min = np.min(data_x_array_filtered, axis=(0,2)) # Minimum pro Kanal
global_max = np.max(data_x_array_filtered, axis=(0,2))  # Maximum pro Kanal
global_mean = np.mean(data_x_array_filtered, axis=(0, 2))  # Mittelwert pro Kanal
global_std = np.std(data_x_array_filtered, axis=(0, 2))  # Standardabweichung pro Kanal


channels = [f"channel_{i}" for i in features]

global_metadata = pd.DataFrame({
    "channel": channels,
    "min": global_min,
    "max": global_max,
    "mean": global_mean,
    "std": global_std,
})

global_metadata
# Out:
#          channel       min       max          mean      std
# 0  channel_C3:A2 -0.000949  0.001038  1.618085e-07  0.00003

# %%
plt.plot(data_x_array_filtered[0].flatten())  # Beispiel für eine Zeitreihe
plt.show()

# %%
data_x_array_filtered=np.array(data_x_array_filtered)

print(f"{type(data_x_array_filtered)}, {data_x_array_filtered.shape}")
print(
    f"univariate = {is_univariate(data_x_array_filtered)}, has missing ={has_missing(data_x_array_filtered)}, equal "
    f"length = {is_equal_length(data_x_array_filtered)}"
)
# Out:
# <class 'numpy.ndarray'>, (6479, 1, 7680)
# univariate = True, has missing =False, equal length = True

# %% [markdown]
# ## 3.2 Label Analysis

# %% [markdown]
# Im folgenden Abschnitt werden die Labels und deren Verteilung detailliert analysiert. Aufgrund der Tatsache, dass der Datensatz hauptsächlich Patienten mit Schlafstörungen umfasst, ist von einer ungleichen Verteilung der Labels auszugehen. Diese Ungleichverteilung kann das Training verschiedener Modelle erheblich beeinflussen. Zudem kann das Wissen über die Verteilung der Labels bei der Auswahl geeigneter Modelle von Nutzen sein, da unterschiedliche Modelltypen variabel auf diese Verteilung reagieren.

# %%
global_percentage_labels, global_count_labels = calculate_label_share(label_y_array_filtered)

# %%
p1 = plt.bar(np.unique(label_y_array_filtered), global_count_labels, color='skyblue')

for index, p in enumerate(p1):
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy()
    plt.text(x+width/2, y+height*1.01, str(global_percentage_labels[index])+'%',ha='center',weight='bold')

    

plt.xlabel('Label')
plt.ylabel('Anzahl')
plt.title('Anteil jedes Labels am gesamten Datensatz')
plt.show()

# %% [markdown]
# Im oben visualisierten Balkendiagramm wird die Verteilung der Labels im importierten Datensatz dargestellt. Wie aus der Abbildung ersichtlich, gibt es ein deutliches Ungleichgewicht bei den Labels "Wach" und "N2". Dies könnte unter anderem auf den Kontext des Datensatzes zurückzuführen sein, da die Patienten, die an dieser Studie teilnehmen, grundsätzlich Schlafstörungen aufweisen. Die restlichen Labels machen daher zusammen nur etwa ein Drittel des gesamten Datensatzes aus.

# %%
patient_label_share_list = []


for patient_id in signals.keys():
    patient_label_share, patient_label_count = calculate_label_share([intervall[1] for intervall in analysis_data[patient_id]["Schlafprofil.txt"]if intervall[1] not in "A" or intervall[1] not in "Artefakt"])
    patient_label_share_list.append({patient_id:{"percentage": patient_label_share, 
                                                 "count":patient_label_count,
                                                 "labels": np.unique([intervall[1] for intervall in analysis_data[patient_id]["Schlafprofil.txt"]if intervall[1] not in "A" or intervall[1] not in "Artefakt"])
                                                 }})
    

all_labels = set()
for entry in patient_label_share_list:
    for key, value in entry.items():
        all_labels.update(value['labels'])
all_labels = sorted(all_labels)

ids = [list(entry.keys())[0] for entry in patient_label_share_list]

# Heatmap-Daten vorbereiten
heatmap_data = pd.DataFrame(index=all_labels, columns=ids)
for entry in patient_label_share_list:
    for entry_id, value in entry.items():
        for label, count in zip(value['labels'], value['count']):
            heatmap_data.loc[label, entry_id] = count

# Fehlende Werte mit 0 auffüllen
heatmap_data = heatmap_data.fillna(0)

plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, cmap="Greens", fmt=".0f")
plt.title('Heatmap der Label-Anzahl pro Patient')
plt.xlabel('Patient')
plt.ylabel('Labels')
plt.show()
# Out:
# /tmp/ipykernel_908/2434259227.py:28: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   heatmap_data = heatmap_data.fillna(0)

# %% [markdown]
# Um dieses Ungleichgewicht genauer zu analysieren, wurde in der obigen Abbildung eine Heatmap erstellt, die die Labelverteilung für jeden einzelnen Patienten detailliert darstellt. Daraus lässt sich ableiten, dass die schwerpunktmäßige Verteilung auf die Labels "Wach" und "N2" keine Anomalie ist, die nur durch einzelne Patienten verursacht wird. Vielmehr zeigt sich diese kontinuierliche Verteilung auf diese beiden Labels bei nahezu allen betrachteten Patienten. Darüber hinaus lässt sich aus diesem Diagramm entnehmen, dass einige Labels, wie die REM-Schlafphase, bei allen betrachteten Patienten nur in so geringem Umfang vorhanden sind, dass dies beim Training oder Testen der Modelle zu einseitigen Bewertungen führen könnte.

# %%
data_train_raw, data_test_raw, label_train_raw, label_test_raw = train_test_split(data_x_array_filtered, label_y_array_filtered, test_size=0.2, random_state=42)
label_train_raw = np.array(label_train_raw)

# %% [markdown]
# Die gefilterten Daten werden nun zu gesplitet durch die im sklearn enthaltene funktion train_test_split.

# %% [markdown]
# # 4. Feature-Extraction-based Models

# %% [markdown]
# Durch die im vorherigen Kapitel erläuterte Formatierung der Daten können diese in spezifischen Transformern verwendet werden, um aus den rohen Datenpunkten einen Feature-Vektor zu extrahieren. Das Aeon-Toolkit enthält dabei verschiedene Ansätze zur Bildung dieses Vektors. Im Rahmen dieser Ausarbeitung wurden daher zwei unterschiedliche Transformer ausgewählt: Catch22 und ROCKET. Während Catch22 eine klassische "Feature-Based"-Transformation darstellt, basiert ROCKET auf einer "Convolution-Based"-Transformation. Diese unterschiedlichen Modelltypen sollen Aufschluss darüber geben, inwiefern die Art der Feature-Extraktion innerhalb unseres Datenkontextes zu unterschiedlichen Ergebnissen führt. Darüber hinaus dient dies zur Verifikation der Ergebnisse, da man ohne ein entsprechendes Vergleichsobjekt keine definitive Aussage über die Qualität des jeweiligen Modells treffen kann.
#
# Das folgende Kapitel gliedert sich in die Anwendung der jeweiligen Transformer. Das Aeon-Toolkit bietet bei der Modellerstellung die Möglichkeit, Modelle entweder mit einer bereits vordefinierten Pipeline zu erstellen oder alternativ nur die Transformation durchzuführen, um die Daten in einem separaten Modell weiterzuverwenden. In diesem Kapitel werden sowohl für Catch22 als auch für ROCKET beide Optionen zur Konstruktion der Modelle genutzt, um zu vergleichen, ob die Standardpipeline bereits effektive Ergebnisse erzeugt.

# %% [markdown]
# ## 4.1.  Feature Extraction via Catch22-Transformer

# %% [markdown]
# Der "Canonical Time-series Characteristics"-Transformer, auch Catch22 genannt, ist ein Ansatz zur featurebasierten Klassifikation von Zeitreihendaten. Das Besondere an dieser Transformationsmethode ist, dass aus den Zeitreihen statistische Merkmale als Features extrahiert werden. Diese Merkmale werden anschließend als Feature-Vektor dargestellt und können zur Konstruktion von maschinellen Lernmodellen verwendet werden.
#
# Dem Namen entsprechend werden aus den Zeitreihendaten 22 spezifische Merkmale extrahiert. Eine Zeitreihe, die diesen Transformer durchläuft, hat danach die Form (n_cases, 22 x n_channels). Zu diesen Merkmalen gehören Parameter wie der Prozentsatz der Ausreißer in einem bestimmten Bereich oder der häufigste Wert in einem Histogramm mit 5 bzw. 10 Bins. Diese Merkmale sind standardisiert und fest definiert. Sie sollen ein möglichst breites Spektrum an verschiedenen Aspekten eines Datensatzes abbilden. Dadurch ist der Transformer sowohl kompakt als auch mit geringem Rechenaufwand betreibbar, wodurch Modelle mit geringerem Ressourcenaufwand konstruiert werden können.
#
# Aufgrund dieser Kompaktheit wurde dieser Transformer bzw. die im Aeon Toolkit definierte Klassifikationspipeline für diese Ausarbeitung ausgewählt. Das resultierende Modell soll eine Basislinie darstellen, die zeigt, ob innerhalb des gegebenen Datenkontextes bereits einfachere Modelle akzeptable Ergebnisse erbringen können.

# %% [markdown]
# ### 4.1.1 Building Catch22-Model

# %%
c22cls = Catch22Classifier()

c22cls.fit(data_train_raw, label_train_raw)
# Out:
# Catch22Classifier()

# %% [markdown]
# Für die Konstruktion des Catch22-Modells wurde im ersten Schritt der im Aeon-Toolkit definierte Catch22Classifier eingesetzt. Dieser transformiert die Rohdaten automatisch in die definierten 22 Parameter und erzeugt ein Modell mit einem standardisierten RandomForestClassifier.

# %% [markdown]
# ### 4.1.2 Evaluate Catch22-Model

# %%
c22_preds = c22cls.predict(data_test_raw)

evaluate_model(label_test_raw, c22_preds)
# Out:
# Genauigkeit des Modells: 0.74
# Eindeutige Werte in label_test: ['N1' 'N2' 'N3' 'Rem' 'Wach']
# Eindeutige Werte in data_pred: ['N1' 'N2' 'N3' 'Rem' 'Wach']
#               precision    recall  f1-score   support
#
#           N1       0.38      0.13      0.20       152
#           N2       0.71      0.86      0.78       482
#           N3       0.85      0.75      0.80       123
#          Rem       0.60      0.45      0.52        84
#         Wach       0.81      0.87      0.84       455
#
#     accuracy                           0.74      1296
#    macro avg       0.67      0.61      0.63      1296
# weighted avg       0.71      0.74      0.72      1296

# %% [markdown]
# Aus diesem ersten Konstruktionsversuch ist ersichtlich, dass die allgemeine Genauigkeit des Modells mit 74% bereits ein hohes Ergebnis aufweist. Wie aus der Konfusionsmatrix zu entnehmen ist, beruht dieses Ergebnis jedoch darauf, dass das Modell viele Datenintervalle als "Wach" oder "N2" klassifiziert, was aufgrund des hohen prozentualen Anteils dieser Klassen im Datensatz häufig zu korrekten Klassifikationen führt. Betrachtet man jedoch die Recall-Werte der Klassen "REM" und "N1", lässt sich ableiten, dass das Modell bei diesen Daten praktisch nur zufällig die Labels zuweist.

# %% [markdown]
# ### 4.1.3 Adapted RandomForrest-Model with Catch22-Data

# %% [markdown]
# Um die Ergebnisse des Catch22Classifier zu verifizieren bzw. zu vergleichen, wurde anschließend ein eigenes Modell auf Basis des RandomForestClassifier mit den Catch22-Feature-Vektoren erstellt. Das Hyperparameter-Tuning wurde in diesem Fall automatisiert durch die Verwendung von GridSearch durchgeführt.

# %%
c22 = Catch22()
data_x_array_catch22 = c22.fit_transform(data_x_array_filtered, label_y_array_filtered)

# %%
data_x_array_catch22.shape
# Out:
# (6479, 22)

# %%
data_train_catch22, data_test_catch22, label_train_catch22, label_test_catch22 = train_test_split(data_x_array_catch22, label_y_array_filtered, test_size=0.2, random_state=42)

# %% [markdown]
# Der GridSearchCV verwendet die Hyperparameter aus dem param_grid Dictionary und sucht durch die Kombination der Hyperparameter nach der Konfiguration, die zu der bestmöglichen Genauigkeit führt. Die Parameter für das param_grid wurden in diesem Beispiel zufällig gewählt.

# %%
param_grid = { 
    'n_estimators': [100, 200, 300], 
    'max_depth': [None, 10, 20, 30], 
    'min_samples_split': [2, 5, 10], 
    'min_samples_leaf': [1, 2, 4], 
    'max_features': ['sqrt', 'log2'] 
}

# %%
rf = RandomForestClassifier()

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2) 
grid_search.fit(data_train_catch22, label_train_catch22)
print(f"Besten Parameter: {grid_search.best_params_}")
# Out:
# Fitting 3 folds for each of 216 candidates, totalling 648 fits
# /home/anon/my_env/lib/python3.12/site-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# Besten Parameter: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}

# %%
#rf_pred = rf.predict(data_test)
rf_pred = grid_search.predict(data_test_catch22)

evaluate_model(label_test_catch22, rf_pred)
# Out:
# Genauigkeit des Modells: 0.73
# Eindeutige Werte in label_test: ['N1' 'N2' 'N3' 'Rem' 'Wach']
# Eindeutige Werte in data_pred: ['N1' 'N2' 'N3' 'Rem' 'Wach']
#               precision    recall  f1-score   support
#
#           N1       0.40      0.12      0.19       152
#           N2       0.68      0.88      0.77       482
#           N3       0.86      0.72      0.78       123
#          Rem       0.57      0.27      0.37        84
#         Wach       0.82      0.87      0.84       455
#
#     accuracy                           0.73      1296
#    macro avg       0.67      0.57      0.59      1296
# weighted avg       0.71      0.73      0.70      1296
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.4s
# ...

# %% [markdown]
# Wie aus den Evaluationsparametern und der Konfusionsmatrix ersichtlich, bewegt sich das Modell in einem ähnlichen Genauigkeitsbereich wie das durch den Catch22Classifier erstellte Modell. Dabei zeigen sich jedoch auch die gleichen Schwächen in Bezug auf den Recall-Wert der weniger vertretenen Labelklassen. Somit konnten die Werte des Catch22Classifier validiert und als bereits optimiert angesehen werden.

# %% [markdown]
# ## 4.2. Feature Extraction via Rocket-Transformer

# %% [markdown]
# Als Vergleichsmodell zu den featurebasierten Extraktionsverfahren wurde der ROCKET (RandOm Convolutional KErnel Transform), auch als ROCKET-Transformer bzw. RocketClassifier bekannt, gewählt. Im Vergleich zu Catch22 liegt der wesentliche Unterschied bei diesem Transformer darin, dass die durch den Transformer extrahierten Features keine feste Definition haben. ROCKET ist daher der Kategorie der "Convolution-Based-Classifiers" zuzuordnen.
#
# Grundbestandteile des ROCKET-Transformers sind die sogenannten Kernels oder Convolutions. ROCKET generiert eine definierte Anzahl zufälliger Kernels. Diese Kernels können beispielsweise Vektoren mit zufällig generierten Zahlenwerten darstellen. Diese Vektoren werden anschließend auf die Zeitreihen angewendet, indem sie mit den Zeitreihenwerten multipliziert und die Ergebnisse addiert werden. Der Kernel wird dabei über die Zeitreihe "geschoben", sodass er auf jeden Zeitwert angewendet wird. Das resultierende Array wird als Aktivierungs-Map bezeichnet. Der sogenannte Pooling-Layer extrahiert dann in der Max-Pooling-Schicht den größten Wert der Aktivierungs-Map. Dieser Wert stellt ein extrahiertes Feature dar. Analog durchlaufen alle weiteren zufällig generierten Kernels diesen Prozess, um bei Bedarf einen Feature-Vektor zu konstruieren.
#
# Durch das zufällige Generieren und Anwenden großer Mengen an Kernels kann ROCKET ein breiteres Spektrum an Merkmalen extrahieren, was für die nachfolgende Klassifikation von Vorteil ist. Ein weiterer Grund für die Auswahl dieses Transformers ist, dass er nicht auf standardisierten Merkmalen basiert. Standardisierte Merkmale können einen gewissen Bias verursachen, wodurch die darauf trainierten Modelle bestimmte Muster und Strukturen möglicherweise nicht beachten. Zudem kann die Generierung und Anwendung variabler Kernels recheneffizienter sein als die Berechnung komplexer fest definierter Parameter.

# %% [markdown]
# ### 4.2.1 Build Model

# %% [markdown]
# Der RocketClassifier im Aeon-Toolkit beinhaltet, analog zum Catch22Classifier, neben dem entsprechenden Transformer auch eine Pipeline, die einen StandardScaler und den RidgeClassifierCV umfasst. Der RidgeClassifierCV ist ein Modell aus der scikit-learn-Bibliothek und stellt einen linearen Klassifikator dar, der ähnlich wie eine lineare Regression die Datenpunkte durch lineare Funktionen trennt. Der Unterschied zu normalen linearen Regressionsklassifikatoren liegt darin, dass der RidgeClassifier Strafparameter einführt, die das Modell vor Überanpassungen bei Extremwerten schützen. Außerdem wird durch eine Cross-Validation im RidgeClassifierCV direkt die besten Hyperparameter ermittelt.

# %%
rocket_clf = RocketClassifier(n_kernels=2000)
rocket_clf.fit(data_train_raw, label_train_raw)
# Out:
# RocketClassifier(n_kernels=2000)

# %% [markdown]
# ### 4.2.2 Evaluate Model

# %%
rocket_pred = rocket_clf.predict(data_test_raw)
evaluate_model(label_test_raw, rocket_pred)
# Out:
# Genauigkeit des Modells: 0.72
# Eindeutige Werte in label_test: ['N1' 'N2' 'N3' 'Rem' 'Wach']
# Eindeutige Werte in data_pred: ['N1' 'N2' 'N3' 'Rem' 'Wach']
#               precision    recall  f1-score   support
#
#           N1       0.44      0.05      0.08       152
#           N2       0.66      0.90      0.76       482
#           N3       0.87      0.61      0.72       123
#          Rem       0.56      0.11      0.18        84
#         Wach       0.79      0.90      0.84       455
#
#     accuracy                           0.72      1296
#    macro avg       0.66      0.51      0.52      1296
# weighted avg       0.69      0.72      0.67      1296

# %% [markdown]
# Nach erfolgreicher Konstruktion des ROCKET-Classifiers lässt sich aus den Ergebnissen eine etwas schlechtere Genauigkeit des allgemeinen Modells ableiten. In Anbetracht der Precision- und Recall-Werte zeigt sich eine ähnliche Schwäche wie beim Catch22-Modell, was die verringerte allgemeine Genauigkeit erklärt. Bei der Analyse der N1- und REM-Werte ist besonders hervorzuheben, dass die Precision im Vergleich zum Catch22-Modell deutlich abgenommen hat. Dies lässt darauf schließen, dass sowohl die korrekte Erkennung solcher weniger vertretenen Klassen als auch die Vorhersagequalität durch die Transformation oder die Verwendung in einem linearen Modell leidet.

# %% [markdown]
# ### 4.2.3. Adapted RandomForrest-Model with Rocket-Data

# %% [markdown]
# Zur Verifizierung der Ergebnisse aus den Schritten 4.2.1 und 4.2.2 werden die ROCKET-Daten nun analog zu Kapitel 4.1.3 in einem RandomForest-Modell abgebildet. Dies soll einerseits die Ergebnisse aus den vorherigen Schritten verifizieren und andererseits genaueren Aufschluss darüber geben, ob das in Kapitel 4.2.1 verwendete RidgeClassifierCV-Modell oder die generelle Transformation der Daten zu den allgemein schlechteren Ergebnissen führen kann.

# %%
rocket = Rocket(n_kernels=2000)
data_x_array_rckt= rocket.fit_transform(data_x_array_filtered, label_y_array_filtered)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 rocket = Rocket(n_kernels=2000)
#       2 data_x_array_rckt= rocket.fit_transform(data_x_array_filtered, label_y_array_filtered)
#
# NameError: name 'Rocket' is not defined

# %%
data_x_array_rckt.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data_x_array_rckt.shape
#
# NameError: name 'data_x_array_rckt' is not defined

# %%
data_train_rckt, data_test_rckt, label_train_rckt, label_test_rckt = train_test_split(data_x_array_rckt, label_y_array_filtered, test_size=0.2, random_state=42)

# %%
rf = RandomForestClassifier()

grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2) 
grid_search.fit(data_train_rckt, label_train_rckt)
print(f"Besten Parameter: {grid_search.best_params_}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 rf = RandomForestClassifier()
#       3 grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, cv=3, n_jobs=-1, verbose=2)
#       4 grid_search.fit(data_train_rckt, label_train_rckt)
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
rf_rckt = grid_search.predict(data_test_rckt)

evaluate_model(label_test_rckt, rf_rckt)

# %% [markdown]
# Wie aus der obigen Grafik ersichtlich, wurden die allgemeinen schlechten Recall-Werte für die Klassen N1 und REM nur marginal verbessert. Dies deutet darauf hin, dass das Modell weiterhin die Labels dieser Klassen zufällig zuweist bzw. den am häufigsten vertretenen Klassen im Datensatz (N2 und Wach) zuordnet. Allerdings ist eine deutliche Verbesserung bei den Precision-Werten zu beobachten, was auf eine gesteigerte Vorhersagequalität des Modells hinweist. Daher kann abgeleitet werden, dass die standardisierte Datenpipeline mit dem RidgeClassifierCV im aktuellen Datenkontext zu einer geringeren Precision führt. Die durch die ROCKET-Transformation selbst erzielten schlechteren Recall-Werte könnten im Vergleich zu Kapitel 4.1.3 darauf hindeuten, dass diese Transformation empfindlicher auf einen unausgeglichenen Label-Datensatz reagiert.

# %% [markdown]
# ## 4.3. Testing Distance Methods with Feature-Vektors

# %% [markdown]
# Die in Kapitel 4.1 und 4.2 erörterten Modelle basieren grundsätzlich auf der Annahme, dass baum-basierte Modellarten, mit Ausnahme des standardmäßigen RocketClassifier, die beste Herangehensweise zur Klassifikation der Schlafphasen darstellen. Um diese Hypothese zu verifizieren, werden im folgenden Kapitel die Catch22-Daten in einem distanzbasierten Modell angewendet. Aufgrund der Simplizität des Algorithmus und der Unterstützung mehrerer Klassen wurde der k-Nearest-Neighbor-Klassifikator (k-NN) gewählt. Die Anwendung bereits transformierter Daten auf ein solches allgemein gültiges Modell soll sowohl als Test als auch als Vergleichswert dienen, um zu eruieren, ob ein fundamental anderes Modell im gegebenen Datenkontext zu besseren Ergebnissen kommt als ein klassischer RandomForest.
#
# Bei der Erstellung des Modells mussten die Daten im ersten Schritt erneut skaliert werden, um die Catch22-Features in einen einheitlichen Wertebereich zu bringen, sodass jedes Feature innerhalb der Distanzberechnung gleichmäßig berücksichtigt wird. Die Optimierung der Hyperparameter wurde, analog zu Kapitel 4.1.3 und 4.2.3, mittels GridSearch durchgeführt, um die bestmögliche Variante des Modells zu erhalten.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier

param_grid = {
    'n_neighbors': range(1, 50),
    'metric': ['euclidean', 'cityblock', 'minkowski', "cosine" ],
    'weights': ['uniform', 'distance']
}

scaler = StandardScaler()

# %%
data_x_array_catch22_scaled= scaler.fit_transform(data_x_array_catch22)
data_train_catch22, data_test_catch22, label_train_catch22, label_test_catch22 = train_test_split(data_x_array_catch22_scaled, label_y_array_filtered, test_size=0.2, random_state=42)

# %%
neigh = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5)
neigh.fit(data_train_catch22, label_train_catch22)

# %%
neigh_predict= neigh.predict(data_test_catch22)

evaluate_model(neigh_predict, label_test_catch22)

# %% [markdown]
# Die allgemeine Performance des KNN-Modells ist, wie dem Accuracy-Wert zu entnehmen ist, vergleichsweise schlechter als bei den baumbasierten Ansätzen. Bei der Betrachtung der Konfusionsmatrix fällt jedoch auf, dass die Werte deutlich diverser verteilt sind. Der Precision-Wert bei den weniger vertretenen Schlafphasen ist besonders markant, da er im Vergleich zu allen anderen baumbasierten Modellen drastisch abgenommen hat. Dementsprechend schlecht fällt die Vorhersagequalität bei diesen Klassen aus. Im Vergleich dazu hat sich der Recall-Wert jedoch nicht signifikant verändert. Tatsächlich scheint es so, als würde sich das Modell nicht mehr nur an den meist vertretenen Klassen orientieren, sondern, wie der vergleichsweise hohe Recall-Wert der N3-Klasse zeigt, auch diese berücksichtigen. Lediglich bei den noch weniger vertretenen Klassen wie N1 und REM bleibt der Recall-Wert auf einem gleich niedrigen Niveau, was erneut auf eine nahezu zufällige Zuordnung dieser Klassen seitens des Modells hindeutet.

# %% [markdown]
# # 5. Deep-Learning Models

# %% [markdown]
# Als konträrer Ansatz zu den featurebasierten Modellen in Kapitel 4 werden im folgenden Kapitel Deep-Learning-Modelle konstruiert, die auf Rohdaten trainiert werden. Dies soll dazu dienen, die eingangs gestellte Forschungsfrage zu untersuchen und eine Vergleichbarkeit der featurebasierten Machine-Learning-Modelle und der Deep-Learning-Modelle zu etablieren.
#
# Bei der Auswahl der Deep-Learning-Modelle wurde sich auf drei separate Modellarten konzentriert. Diese wurden im Rahmen dieser Ausarbeitung mit verschiedenen Hyperparametern getestet, um genauer zu analysieren, wie diese sich auf die Modelle auswirken und inwiefern eine Optimierung der Modelle vorgenommen werden kann, um sie gegebenenfalls vergleichbar zu machen. Die Hyperparameter, die zum Bau der Modelle verwendet wurden, sind Einstiegswerte, die manuell getestet wurden, jedoch kein ultimatives Optimum darstellen.
#
# Für die Datentransformation werden lediglich die erhaltenen Daten aus Kapitel 3 skaliert und per vordefinierter Train-Test-Methode aufgeteilt. Sämtliche Deep-Learning-Modelle basieren somit auf den rohen Zeitreihendaten. Es bleibt zu beobachten, ob diese Rohdatenverarbeitung im Rahmen des gegebenen Datenkontextes bessere Modelle konstruieren lässt, da die Daten nicht erst abstrahiert werden müssen wie bei einem featurebasierten Transformer.

# %%
from keras.src.optimizers import Adam
from aeon.classification.deep_learning import FCNClassifier, MLPClassifier, ResNetClassifier
from aeon.transformations.collection import MinMaxScaler

# %%
scaler = MinMaxScaler()

data_x_array_raw_scaled= scaler.fit_transform(data_x_array_filtered)
data_train_dl, data_test_dl, label_train_dl, label_test_dl = train_test_split(data_x_array_raw_scaled, label_y_array_filtered, test_size=0.2, random_state=42)

# %%
def visualize_loss_and_accuracy(model):
    acc = model.summary()["accuracy"]
# val_acc = tcnn.history.history['val_accuracy']
    loss = model.summary()["loss"]
#val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    plt.figure()
    plt.plot(epochs, acc, 'green', label='Training accuracy')
#plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
    plt.title('Training and validation accuracy')
    plt.legend()


    plt.figure()
    plt.plot(epochs, loss, 'red', label='Training loss')
    #plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss')
    plt.legend()

    plt.show()

# %% [markdown]
# ## 5.1. Basline MLP-Model

# %% [markdown]
# Um eine allgemeine Basislinie festzulegen, wird ein einfaches Multilayer-Perceptron-Modell (MLP) erstellt. Dies soll einerseits dazu dienen, weitere Deep-Learning-Modelle mit einem Basiswert zu vergleichen, und andererseits erörtern, wie sich eine eher einfache Modellart innerhalb des Datenkontextes verhält. Das MLP-Modell kann daher als eine Art "Standardmodell" angesehen werden, da es im Verhältnis nur wenige Hidden-Layer besitzt, wodurch die Komplexität des Modells einfach gehalten wird.

# %%
mlp = MLPClassifier(activation="softmax", n_epochs= 25, optimizer=Adam(learning_rate=0.0001), verbose=True)

# %%
mlp.fit(data_train_dl, np.array(label_train_dl))

# %%
mlp_pred = mlp.predict(data_test_dl)

evaluate_model(label_test_dl, mlp_pred)

# %%
visualize_loss_and_accuracy(mlp)

# %% [markdown]
# Wie aus den beiden Kurven und der Konfusionsmatrix ersichtlich, ist dieses Modell für die Klassifikation der Daten nicht geeignet. Es weist zwar eine verhältnismäßig hohe Accuracy auf, diese kommt jedoch nur dadurch zustande, dass das Modell viele Datensätze pauschal aufgrund ihrer statistischen Mehrheit als N2 klassifiziert, ohne diese Zuordnung wirklich zu lernen. Daraus lässt sich schließen, dass diese Modellart die komplexen Strukturen des Datensatzes aufgrund ihrer minimalen Layer-Struktur nicht nachvollziehen kann.

# %% [markdown]
# ## 5.2 FCN-Model

# %% [markdown]
# Um nun ein Modell mit einer komplexeren Layerstruktur zu testen, wird im folgenden Kapitel eine besondere Art von Convolutional Neural Network (CNN) konstruiert, das sogenannte Fully Convolutional Network (FCN). Das FCN weist Ähnlichkeiten mit einem herkömmlichen CNN auf. Ähnlich zu dem bereits in Kapitel 4.2 erörterten RocketClassifier, welcher ebenfalls auf Convolutions basiert, durchlaufen die Daten bei einem FCN mehrere Convolutional Layers. In diesen Layern werden die Kernels über die Daten "geschoben", wodurch eine Feature-Map entsteht. Durch Pooling-Schichten werden diese Maps zusammengefasst, was die Größe reduziert und möglicherweise Strukturen hervorhebt.
#
# Diese Modelle sind vor allem bei der Klassifikation von Bildern beliebt, da durch das Zusammenspiel von Convolutional und Pooling Layers Strukturen auf einem Bild hervorgehoben werden, die sich danach kategorisieren lassen. Das Aeon Toolkit bietet jedoch einen eigenen Klassifikator, der auf die Verwendung von Zeitreihendaten fokussiert ist.

# %%
tcnn = FCNClassifier(activation='tanh', n_epochs=80, optimizer=Adam(learning_rate=0.00001),  verbose=True, random_state=42)

# %%
tcnn.fit(data_train_dl, np.array(label_train_dl))

# %%
tcnn_pred = tcnn.predict(data_test_dl)

evaluate_model(label_test_dl, tcnn_pred)

# %%
visualize_loss_and_accuracy(tcnn)

# %% [markdown]
# Wie aus den obigen Abbildungen und Tabellen ersichtlich, stellt die Verwendung des FCNClassifier eine grundlegende Verbesserung dar. Allerdings ist diese Verbesserung erneut auf die statische Veranlagung des Modells zurückzuführen, die am häufigsten verwendeten Labels grundsätzlich jedem Datensatz zuzuweisen. Im Vergleich zum MLP-Modell weist das FCN-Modell nun jedoch sowohl die Wach- als auch die N2-Schlafphase den Datensätzen zu. Aufgrund dessen ist anzunehmen, dass durch die erhöhte Komplexität des FCN-Modells die Strukturen und Muster innerhalb des Datensatzes besser abgebildet werden konnten. Dies reicht jedoch noch nicht aus, um auch weniger vertretene Klassen zu berücksichtigen.

# %% [markdown]
# ## 5.3. ResNet

# %% [markdown]
# Das Residual Network, oder ResNetClassifier, stellt einen der vergleichsweise komplexeren Deep-Learning-Modelltypen dar. Ähnlich wie ein CNN oder FCN enthält es verschiedene Convolutional Layers, die Muster aus den Daten hervorheben. Die Besonderheit liegt jedoch in der Verwendung sogenannter "Residual Blocks", die eine Shortcut-Verbindung enthalten, wodurch Eingangssignale direkt an den Ausgang des Blocks weitergeleitet werden. Dadurch können Informationen direkter an die unterliegenden Schichten weitergegeben werden, ohne durch weitere Transformationen zu stark abstrahiert zu werden. Dies ermöglicht den Aufbau von deutlich tieferen und somit auch komplexeren Netzwerken.
#
# Da die Ergebnisse aus den vorherigen Modellen darauf hindeuten, dass der Datenkontext einen tieferen Modellaufbau verlangt, wurde im Zuge dessen die Konstruktion dieses Netzwerktyps gewählt.

# %%
resnet= ResNetClassifier( activation="softmax", optimizer=Adam(learning_rate=0.001),n_epochs= 20, batch_size=8, verbose= True)

# %%
resnet.fit(data_train_dl, np.array(label_train_dl))

# %%
resnet_pred = resnet.predict(data_test_dl)

evaluate_model(label_test_dl, resnet_pred)

# %%
visualize_loss_and_accuracy(resnet)

# %% [markdown]
# Wie aus den Abbildungen und Tabellen zu entnehmen ist, wurde durch die Verwendung des ResNetClassifier erneut die Genauigkeit erhöht, was darauf schließen lässt, dass die Verwendung tieferer Netzwerke im vorliegenden Datenkontext tatsächlich bessere Ergebnisse erzielen kann. Allerdings besteht weiterhin eine Lücke bei der Erkennung weniger vertretenen Klassen. Die erhöhte Genauigkeit resultiert daher nicht aus einer allgemeinen Verbesserung des Modells, sondern erneut aus der verbesserten Vorhersage der häufig vertretenen Klassen Wach und N2, wie aus den Precision- bzw. Recall-Werten der Klassen hervorgeht. Im Vergleich zu den vorherigen Modellen kann jedoch angemerkt werden, dass bei den Vorhersagen des ResNet-Modells auch die N3-Klasse, wenn auch nur in geringem Maße, berücksichtigt wurde.

# %% [markdown]
# # 6. Evaluation

# %% [markdown]
# Mit der erstellung der Modele soll nun die Evaluation der Modele erfolgen. Dies schließt einerseits die Interpretation udn berwertung der Ergebnisse mit ein, als auch die möglichen Weiterentwicklungsmöglichkeiten die sich im Rahmen des Hyperparamter tuning, Modeloptimierung oder Datenausweritung ergeben können.

# %% [markdown]
# ## 6.1. Bewertung der Ergebnisse

# %% [markdown]
# Im folgenden Kapitel werden die Modelvarainten mit der besten Accuarcy direkt gegenübergestellt und auf Basis der eingangs erwäehnten Zielstellung bewertet und interpretiert. Zu diesen besten Modelen zählen
#
# - Catch22
# - ROCKET mit RandomForrest
# - ResNet
#
# Die sonstigen modele wie der KNN mit den Catch22 Daten oder das FCN-Model sind entweder hinter den Genaugikeitswerten der anderen Modele oder grundästlzich ungeeignet für die Nutzung im Datenkontext. Für die Bewertung der Modele werden die ConfusuionsMatrxien aneinander gereiht um sie direkt Vergleichen zu können. Des Weiteren werden die Bewertungsmertiken iwe Percsion udn Recall für jede Klasse und jedes Model innerhalb eines Diagramms vergleichbar dargestellt.

# %%
test_labels_list = [
    label_test_raw, 
    label_test_rckt,
    label_test_dl      
]

predictions_list = [
    c22_preds, 
    rf_rckt,       
    resnet_pred     
]

titles = ["Catch22", "ROCKET with RF", "ResNet"]

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, (test_labels, predictions, title) in enumerate(zip(test_labels_list, predictions_list, titles)):
    cm = confusion_matrix(test_labels, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.unique(test_labels))
    disp.plot(ax=axes[i], cmap="Blues", values_format='d')
    axes[i].set_title(title)
    axes[i].grid(False) 

plt.tight_layout()
plt.show()

# %%
reports = {
    'Catch22': classification_report(label_test_raw, c22_preds, output_dict=True),
    'ROCKET': classification_report(label_test_rckt, rf_rckt, output_dict=True),
    'ResNet': classification_report(label_test_dl, resnet_pred, output_dict=True),
}

# %%
def create_report_chart(report_dict,parameter):
    recall_data = {}
    for model_name, report in report_dict.items():
        recall_data[model_name] = {k: v[parameter] for k, v in report.items() if k not in ['accuracy', 'macro avg', 'weighted avg']}
        
    
    classes = list(next(iter(recall_data.values())).keys())
    models = list(recall_data.keys())

    # Daten vorbereiten
    x = np.arange(len(classes)) 
    width = 0.25 
    offsets = np.linspace(-width, width, len(models)) 
    
    # Plot erstellen
    plt.figure(figsize=(10, 6))
    
    for i, model in enumerate(models):
        recalls = [recall_data[model][cls] for cls in classes]
        plt.bar(x + offsets[i], recalls, width, label=model)
    
    
    plt.xticks(x, classes)
    plt.xlabel("Labels")
    plt.ylabel("Recall")
    plt.title(f"{parameter}-Values per Model and per Labels")
    plt.legend(title="Model")


    plt.tight_layout()
    plt.show()

# %%
create_report_chart(reports, "recall")

# %% [markdown]
# Wie aus dem obrigen Recall-Vergelichsdiagramm zu entnehemen ist wurde

# %%
create_report_chart(reports, "precision")

# %% [markdown]
# ## 6.2. Weiterentwicklungsmöglichkeiten

# %% [markdown]
# Das grundsätzliche Problem weshalb im momentanen Datenkontext einige Modele deutlische schwächen bei dem erlenen Der internen Strukturen haben ist die Label-Vertielung bei den Datensätzen. Nun ist es so das diese Ausarbeitung nur ein Proof of Concept darstellt, welche nur einen kleinen Teil der eigentlichen Datenmenge zurückgreift. Es besteht die also die Möglichkeit den zu betrachtenden Datensatz zu erweitern. Dafür müsste jedoch im vorhinein eine analyse des Datensatzes stattfinden welche ermittelt ob Labelvertielung bei einbezieung weitere Patieten konsequnt eine höhere Verteilung bei dem label N2 und Wach aufweist. Wie wir aus der Heatmap in kapitel 3.2. entnehmen können weisen der hier zufällig ausgweählten patienten eine ungleiche Labelverteilung auf, jeodch nicht alle. Daher müsste der Datensatz so angepasst werden das sich die Labelverteilung im mittel ausgleicht.

# %% [markdown]
# Um diese Datenungleicheit auszugelciehn aknn jeddoch auch neben der Erweiterung des Datensatzes einige Maßnahmen beim erstellen der Modele mit betrachtet werden. Methoden um eine Datenimbalang auszugelciehn sind unteranderem:
#
# - SMOTE (Synthetic Minority Over-sampling Technique): das künstliche generiern von synthetischen Datenpunkten der Minderheitsklassen
# - Gewichtungen erstellen und bei der Konstruktion der Modelle mitgeben.
# - Verlsustfunktion anpassen: Wie aus den obrigen Modelen zu entnehmen ist wurde mit den standard Verlustfunktionen gearbeitet. Anstelle dieser Funktionen können auch eigene Verlsutfunktione defineiert werden um z.B. die Recall-Werte zu optimieren.

# %% [markdown]
# Neben der Ausbesserung der Daten könen auch die Modle mit ihren Hyperparametn optimiert werden. Die Baumbasierten Modele waren in den bisherigen Tests deutlich optimierter als Vergleichsmodele. Diesen können weiter optimniert werden in z.b. der Bereich der GridSearches ausgeweritet wird. Ein Deep Leaning Model auf das gleiche Niveau zu bringen erfodert einerseits auch intensiveres (ggf. automatisiertesres) Hyperparametertuning aber wie auch aus dem Vergleich zwischen den FNC und dem ResNet Model ersichtlich wurde das hinzufügen tieferer Schichten. Da dies wiederrum detuliche recehninsetnsivere prozesse veruschat ist die Optimierung der Baumbasieren Modele wie des Catch22 im Aktuellen kontxt zu bevorzugen.
